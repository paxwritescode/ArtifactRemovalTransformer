# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
sample_input = pd.read_csv("sampledata/sampledata.csv", header=None).to_numpy()
sample_input.shape

# %%
x_sample_before = np.arange(0, 1, 1/10000)
len(x_sample_before)
sample_channels = len(sample_input)
for i in range(1, sample_channels):
    plt.plot(x_sample_before, sample_input[i])
    break

# %%
sample_output = pd.read_csv("sampledata/outputsample.csv", header=None).to_numpy()
sample_output.shape

# %%
sample_channels

# %%
len(x_sample_after)

# %%
x_sample_after = np.arange(0, 1, 1/9216)
len(x_sample_after)
sample_channels = len(sample_output)
for i in range(0, sample_channels):
    plt.plot(x_sample_after, sample_output[i])
