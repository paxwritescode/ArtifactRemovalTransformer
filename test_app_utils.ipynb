# %%
from app_utils import match_name, align_coords, save_figure, mapping_result
# Step 1: Define the initial input structure
stage1_info = {
    "fileNames": {
        "inputData": "our_chanlocs.loc"
    }
}

# Step 2: Run the first stage to prepare data
stage1_info, channel_info, tpl_montage, in_montage = match_name(stage1_info)

# Step 3: Align coordinates using TPS
channel_info = align_coords(channel_info, tpl_montage, in_montage)

# Step 4: (Optional) Save visualization figures and update css_position
channel_info = save_figure(channel_info, tpl_montage, "aligned_input.png", "mapped_input.png")

# Step 5: Generate final mapping and save to file
stage1_info, channel_info = mapping_result(stage1_info, channel_info, "mapped_output.json")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[2], line 10
#       3 stage1_info = {
#       4     "fileNames": {
#       5         "inputData": "our_chanlocs.loc"
#       6     }
#       7 }
#       9 # Step 2: Run the first stage to prepare data
# ---> 10 stage1_info, channel_info, tpl_montage, in_montage = match_name(stage1_info)
#      12 # Step 3: Align coordinates using TPS
#      13 channel_info = align_coords(channel_info, tpl_montage, in_montage)
#
# File ~/Polytech/eeg_practice/ArtifactRemovalTransformer/app_utils.py:53, in match_name(stage1_info)
#      50 def match_name(stage1_info):
#      51 	# read the location file
#      52 	loc_file = stage1_info["fileNames"]["inputData"]
# ---> 53 	tpl_montage, in_montage, tpl_dict, in_dict = read_montage(loc_file)
#      54 	tpl_names = tpl_montage.ch_names
#      55 	in_names = in_montage.ch_names
#
# File ~/Polytech/eeg_practice/ArtifactRemovalTransformer/app_utils.py:24, in read_montage(loc_file)
#      23 def read_montage(loc_file):
# ---> 24 	tpl_montage = read_custom_montage("./template_chanlocs.loc")
#      25 	in_montage = read_custom_montage(loc_file)
#      26 	tpl_names = tpl_montage.ch_names
#
# File <decorator-gen-88>:12, in read_custom_montage(fname, head_size, coord_frame, verbose)
#
# File ~/micromamba/envs/art/lib/python3.10/site-packages/mne/channels/montage.py:1636, in read_custom_montage(fname, head_size, coord_frame, verbose)
#    1611 from ._standard_montage_utils import (
#    1612     _read_brainvision,
#    1613     _read_csd,
#    (...)
#    1618     _read_xyz,
#    1619 )
#    1621 SUPPORTED_FILE_EXT = {
#    1622     "eeglab": (
#    1623         ".loc",
#    (...)
#    1633     "xyz": (".csv", ".tsv", ".xyz"),
#    1634 }
# -> 1636 fname = str(_check_fname(fname, overwrite="read", must_exist=True))
#    1637 _, ext = op.splitext(fname)
#    1638 _check_option("fname", ext, list(sum(SUPPORTED_FILE_EXT.values(), ())))
#
# File <decorator-gen-0>:12, in _check_fname(fname, overwrite, must_exist, name, need_dir, check_bids_split, verbose)
#
# File ~/micromamba/envs/art/lib/python3.10/site-packages/mne/utils/check.py:302, in _check_fname(fname, overwrite, must_exist, name, need_dir, check_bids_split, verbose)
#     300             raise PermissionError(f"{name} does not have read permissions: {fname}")
#     301 elif must_exist:
# --> 302     raise FileNotFoundError(f'{name} does not exist: "{fname}"')
#     304 return fname
#
# FileNotFoundError: File does not exist: "/Users/paks/Polytech/eeg_practice/ArtifactRemovalTransformer/template_chanlocs.loc"
